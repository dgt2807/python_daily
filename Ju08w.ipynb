# %% [markdown]
# ## 그래프
# ### 앤스콤 데이터 집합 ->그래프
# * 평균 분산 같은 수치값이 같고, 상하관계 회귀선이 같은 데이터???

# %%
import seaborn as sns
anscombe = sns.load_dataset("anscombe",engine='python')
print(anscombe)
print(type(anscombe))
#dataset 열이 데이터 그룹 구분 (4개의 데이터 셋 _동일해 보이나 다르다)
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
dataset1=anscombe[anscombe['dataset']=='I']  #i 랜다 이게 ㅋ  로마자 위에 4개 구분된거 ㅋ
print(dataset1)
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
plt.plot(dataset1['x'],dataset1['y'])
# plot method >>선 그래프

# %%
plt.plot(dataset1['x'],dataset1['y'],'o') #'^' 점 의 모양 변경 가능  색도  c='' 식으로 변경

# %% [markdown]
# ### matplotlib으로 그래프
# >1. 기본틀
# * 격자
# * 격자에 그래프 하나씩 추가 왼->오
# * 1행을 채우고 그다음 2번 행에서 왼-> 오

# %%
dataset2=anscombe[anscombe['dataset']=='II']
dataset3=anscombe[anscombe['dataset']=='III']
dataset4=anscombe[anscombe['dataset']=='IV']

#plt.plot(dataset3['x'],dataset3['y'])

# %%
#격자 
fig = plt.figure()
axes1= fig.add_subplot(2,2,1)  # 행 크기, 열 크기, 
axes2= fig.add_subplot(2,2,2)
axes3= fig.add_subplot(2,2,3)
axes4= fig.add_subplot(2,2,4)

# %%
# 그래프 삽입
axes1.plot(dataset1['x'],dataset1['y'],c='g') 
axes2.plot(dataset3['x'],dataset3['y'],'o',c='k')  #3번 데이터셋
axes3.plot(dataset2['x'],dataset2['y'],c='r')  #2번 데이터 셋
axes4.plot(dataset4['x'],dataset4['y'],c='r')
fig

# naming
axes1.set_title("dataset1")
axes3.set_title("dataset3")
axes2.set_title("dataset2")
axes4.set_title("dataset4")
fig.suptitle('Anscombe Data')
fig
# 수치로 봤을 때는 값이  동일해서 같은 그래프 일거라 생각하지만 시각화르 한다면 모두 다르게 나온다.

# 이름과 x축 겹치는 거 떼어내줌
fig.tight_layout()
fig

#아직까진seaborn에서 데이터만 가져옴  사용안함

# %% [markdown]
# ### 히스토그램, 산점도, 박스 그래프

# %%
tips = sns.load_dataset("tips")    #이거 의미 해석
print(tips.head())
print(type(tips.head()))

#인덱스_  행의 속성명 같은  포지션
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
tips.loc[[23],['smoker']]
#tips.iloc[[23]]
# Out:
#    smoker
# 23     No

# %%
fig = plt.figure()
axes1= fig.add_subplot(1,1,1)    # x , y 축

# %% [markdown]
# #### 일변량 그래프

# %%
axes1.hist(tips['total_bill'],bins=10)  # x축 의 간격을 10으로 
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')

fig    #그래프 지정하고 나면 꼭 사용할것

# %% [markdown]
# #### 산점도 그래프

# %%
scatter_plot=plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'],tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Tip')
#ctrl+ / 다범위 주석
# 산점도 그래프는  fig 안써줌
# Out:
# Text(0, 0.5, 'Tip')

# %%
# 경고 무시
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# #### 박스 그래프
# * 이산형 변수 m f 처럼 구분된 값    명목변수
# * 연속형 변수 셀수 없는 변위의 값
# https://dbrang.tistory.com/1086

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)  #https://www.delftstack.com/ko/howto/matplotlib/how-to-make-different-subplot-sizes-in-matplotlib/

axes1.boxplot(
    [tips[tips['sex']== 'Female']['tip'],
     tips[tips['sex']== 'Male']['tip']],
    labels=['Female','Male'])
axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# #### 다변량 변수  _산점도로

# %%
def recode_g(sex):
    if sex =='Female':
        return 0 
    else:
        return 1

    # s_color 이라는 coloumn 열 추가  tip의 sex 속성 recode_g 함수를 broadcast 식->apply 으로 적용하겠다. 어디에? 추가된 열에 
tips['s_color'] = tips['sex'].apply(recode_g) 
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size s_color
# 0       16.99  1.01  Female     No  Sun  Dinner     2       0
# 1       10.34  1.66    Male     No  Sun  Dinner     3       1
# 2       21.01  3.50    Male     No  Sun  Dinner     3       1
# 3       23.68  3.31    Male     No  Sun  Dinner     2       1
# 4       24.59  3.61  Female     No  Sun  Dinner     4       0

# %%
scatter_plot =plt.figure()
axes1 =scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x=tips['total_bill'],
    y=tips['tip'],
    s=tips['size']*10,  #원의 크기 --식사인원
    c=tips['s_color'],  #color
    alpha=0.5)

# %% [markdown]
# #### 다변량 변수  _히스토그램으로
# * seaborn  라이브러리  , 히스토그램 그리려면 subplots, displot method 사용
# * distplot method 기본틀 만듬 /total _bill method : total bill 열 데이터 전달
# * seaborn ->https://seaborn.pydata.org/introduction.html

# %%
import seaborn as sns
tips=sns.load_dataset("tips") 
ax =plt.subplots()
ax = sns.distplot(tips['total_bill'])
ax.set_title('Totla Bill histogram')
# Out:
# Text(0.5, 1.0, 'Totla Bill histogram')

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], kde =False) # kernal Density Estimation 커널 밀도 추정
ax.set_title('Totla Bill histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], hist =False) # histogram  /   6번째 tips 찾기
ax.set_title('Totla Bill histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#rug인자 추가 그래프의 축에 동일한 길이의 직선을 붙여 데이터의 밀집 정도 표현 그래프
hiost_den_rug, ax= plt.subplots()
ax = sns.distplot(tips['total_bill'], rug =True) 
ax.set_title('Totla Bill histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# #### count그래프 이산값 나타낸 그래프

# %%
ax=plt.subplots()
ax = sns.countplot('day', data =tips) 
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='day',y='total_bill',data=tips)
plt.show()

# %%
# matplot 으로 그린것 과 seaborn 으로 그린것의 차이를 구분하자
#x 축의 요소와 y축의 요소도 변경해보자

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='day',y='total_bill', hue='smoker',data=tips, palette="Set3")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.swarmplot(x='day',y='total_bill',data=tips, color='.5')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='day',y='total_bill', hue='smoker',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips, color='.25')
plt.show()

# %% [markdown]
# ### seaborn 라이브러리으로 산점도 그래프 그리기
# * regplot method 사용  산점도 와 회귀선

# %%
ax=plt.subplots()
ax= sns.regplot(x='total_bill',y='tip',data=tips)  # regplot  회귀선인듯
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax=plt.subplots()
ax= sns.regplot(x='total_bill',y='tip',data=tips, fit_reg=False)  #회귀선 없애기
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# #### jointplot

# %%
joint= sns.jointplot(x='total_bill',y='tip',data=tips)  
joint.set_axis_labels(xlabel='Total Bill',ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.08)
# Out:
# Text(0.5, 1.08, 'Joint Plot of Total Bill and Tip')

# %%
hexbin=sns.jointplot(x="total_bill", y="tip",data=tips, kind='hex')
hexbin.set_axis_labels(xlabel='Total Bill',ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.08)
# Out:
# Text(0.5, 1.08, 'Hexbin Joint Plot of Total Bill and Tip')

# %% [markdown]
# #### 이차원 밀집도

# %%
kde, ax =plt.subplots()
ax=sns.kdeplot(data=tips['total_bill'],data2=tips['tip'],shade=True)
ax.set_title('Kerne Density Plot of Total Bill and Tip')
#ax.set_axis_labels(xlabel='Total Bill',ylabel='Tip')   #이건 왜 안될까?
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# #### barplot
# * barplot은 지정한 변수의 평균을 계산하여 그린다
# * 시간에 따라 지불한 비용의 평균을 그래프로.

# %%
ax=plt.subplots()
ax= sns.barplot(x='time',y='total_bill',data=tips)
ax.set_title('Bar Plot of Average Total Bill for Time of Day')
#ax.set_axis_labels(xlabel='Total Bill',ylabel='Tip')   #이게 안되는 친구들은 아래거로 만 된다..
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax=plt.subplots()
ax= sns.violinplot(x='time',y='total_bill',data=tips)
ax.set_title('Violin Plot of Average Total Bill for Time of Day')
#ax.set_axis_labels(xlabel='Total Bill',ylabel='Tip')  #ax=subplot
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax=plt.subplots()
ax= sns.violinplot(x='time',y='total_bill',hue='sex',data=tips,split=True)
#ax= sns.violinplot(x='time',y='total_bill',hue='sex',data=tips)
ax.set_title('Violin Plot of Average Total Bill for Time of Day')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#sns.set_theme(style="dark")

# Simulate data from a bivariate Gaussian
n = 10000
mean = [0, 0]
cov = [(2, .4), (.4, .2)]
rng = np.random.RandomState(0)
x, y = rng.multivariate_normal(mean, cov, n).T

# Draw a combo histogram and scatterplot with density contours
f, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(x=x, y=y, s=5, color=".15")
#sns.histplot(x=x, y=y, bins=50, pthresh=.1, cmap="mako")
#sns.kdeplot(x=x, y=y, levels=5, color="w", linewidths=1)

# %%
#### pie plot 얘는 plot라이브러리인가.. sns인가..

# %%
labels ='Frogs','Hogs','Dogs','Logs'
sizes=[15,30,45,10]  #비율
explode=(0,0.1,0.3,0)  #돌출 explode

fig1, ax1=plt.subplots()
ax1.pie(sizes,explode=explode,labels=labels, autopct='%1.1f%%',shadow=True, startangle=90) #startangle 반시계 방향 으로 ㄱㄱ
ax1.axis('equal')                                          # autopct는 부채꼴 안에 표시될 숫자의 형식 소숫점 첫째까지 인듯.
plt.show()

# %% [markdown]
# #### 한글  안깨지게 인코딩

# %%
from matplotlib import font_manager, rc
#기호 꺠짐 방지  마이너스 기호
plt.rcParams['axes.unicode_minus']=False
#아래가 한글
f_patch = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname= f_patch).get_name()
rc('font', family = font_name)

# %%
labels ='개구리','Hogs','Dogs','Logs'
sizes=[15,30,45,10]  #비율
fig1, ax1=plt.subplots()
ax1.pie(sizes,explode=explode,labels=labels, autopct='%1.1f%%',shadow=True, startangle=90) #startangle 반시계 방향 으로 ㄱㄱ
ax1.axis('equal')                                          # autopct는 부채꼴 안에 표시될 숫자의 형식 소숫점 첫째까지 인듯.
plt.show()

# %% [markdown]
# ## Ju07u 복습

# %%
import pandas as pd

# %%
dates = pd.date_range('20190301',periods=6)

# %%
import numpy as np
df =pd.DataFrame(np.random.randn(6,4), index=dates, columns=['A','B','C','D'])
 #임의로 날짜 집어넣기

# %%
df
# Out:
#                    A         B         C         D
# 2019-03-01  1.104579 -0.400718 -0.578864 -0.212217
# 2019-03-02 -0.230746  0.875059  1.503603 -0.480797
# 2019-03-03  0.029991 -0.836841  0.292812 -1.237906
# 2019-03-04  0.531912 -1.408266 -1.877995 -1.911272
# 2019-03-05 -0.207109 -0.913612 -0.411280 -0.390380
# 2019-03-06  1.219661  0.830783  0.547277  0.087125

# %%
df.index
# Out:
# DatetimeIndex(['2019-03-01', '2019-03-02', '2019-03-03', '2019-03-04',
#                '2019-03-05', '2019-03-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.values
# Out:
# array([[ 1.10457945, -0.40071812, -0.57886395, -0.21221726],
#        [-0.23074611,  0.87505872,  1.50360283, -0.48079701],
#        [ 0.02999101, -0.83684072,  0.29281204, -1.2379062 ],
#        [ 0.5319125 , -1.40826633, -1.87799508, -1.91127233],
#        [-0.20710895, -0.9136124 , -0.41128018, -0.39038043],
#        [ 1.21966075,  0.83078251,  0.54727662,  0.08712496]])

# %% [markdown]
# #### 정렬 함수

# %%
df.describe()  #데이터 값 정리
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.408048 -0.308933 -0.087408 -0.690908
# std    0.646315  0.955204  1.151636  0.742622
# min   -0.230746 -1.408266 -1.877995 -1.911272
# 25%   -0.147834 -0.894419 -0.536968 -1.048629
# 50%    0.280952 -0.618779 -0.059234 -0.435589
# 75%    0.961413  0.522907  0.483660 -0.256758
# max    1.219661  0.875059  1.503603  0.087125

# %%
df.sort_values(by='A')  #A 기준 정렬
# Out:
#                    A         B         C         D
# 2019-03-02 -0.230746  0.875059  1.503603 -0.480797
# 2019-03-05 -0.207109 -0.913612 -0.411280 -0.390380
# 2019-03-03  0.029991 -0.836841  0.292812 -1.237906
# 2019-03-04  0.531912 -1.408266 -1.877995 -1.911272
# 2019-03-01  1.104579 -0.400718 -0.578864 -0.212217
# 2019-03-06  1.219661  0.830783  0.547277  0.087125

# %%
df.sort_values(by='A',ascending=False)  #내림차순
# Out:
#                    A         B         C         D
# 2019-03-06  1.219661  0.830783  0.547277  0.087125
# 2019-03-01  1.104579 -0.400718 -0.578864 -0.212217
# 2019-03-04  0.531912 -1.408266 -1.877995 -1.911272
# 2019-03-03  0.029991 -0.836841  0.292812 -1.237906
# 2019-03-05 -0.207109 -0.913612 -0.411280 -0.390380
# 2019-03-02 -0.230746  0.875059  1.503603 -0.480797

# %%
df['A']
# Out:
# 2019-03-01    1.104579
# 2019-03-02   -0.230746
# 2019-03-03    0.029991
# 2019-03-04    0.531912
# 2019-03-05   -0.207109
# 2019-03-06    1.219661
# Freq: D, Name: A, dtype: float64

# %%
df.loc[:,['A']]
# Out:
#                    A
# 2019-03-01  1.104579
# 2019-03-02 -0.230746
# 2019-03-03  0.029991
# 2019-03-04  0.531912
# 2019-03-05 -0.207109
# 2019-03-06  1.219661

# %%
df[0:3] #행 가져오기
# Out:
#                    A         B         C         D
# 2019-03-01  1.104579 -0.400718 -0.578864 -0.212217
# 2019-03-02 -0.230746  0.875059  1.503603 -0.480797
# 2019-03-03  0.029991 -0.836841  0.292812 -1.237906

# %%
#df.iloc[['date']=='2019-03-01',:]
df.loc['2019-03-01',['A']]
# Out:
# A    1.104579
# Name: 2019-03-01 00:00:00, dtype: float64

# %%
df.loc['2019-03-01':'2019-03-02',['A','B']]
# Out:
#                    A         B
# 2019-03-01  1.104579 -0.400718
# 2019-03-02 -0.230746  0.875059

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2019-03-01  1.104579 -0.400718
# 2019-03-02 -0.230746  0.875059
# 2019-03-03  0.029991 -0.836841
# 2019-03-04  0.531912 -1.408266
# 2019-03-05 -0.207109 -0.913612
# 2019-03-06  1.219661  0.830783

# %%
df.iloc[0:2]
# Out:
#                    A         B         C         D
# 2019-03-01  1.104579 -0.400718 -0.578864 -0.212217
# 2019-03-02 -0.230746  0.875059  1.503603 -0.480797

# %%
df.iloc[0:2,0:2]
# Out:
#                    A         B
# 2019-03-01  1.104579 -0.400718
# 2019-03-02 -0.230746  0.875059

# %%
#iloc 와 loc 둘다 index를 다룬다.

# %%
df.iloc[[0,1,3],0:2]
# Out:
#                    A         B
# 2019-03-01  1.104579 -0.400718
# 2019-03-02 -0.230746  0.875059
# 2019-03-04  0.531912 -1.408266

# %%
df.loc[:,['A']]
# Out:
#                    A
# 2019-03-01  1.104579
# 2019-03-02 -0.230746
# 2019-03-03  0.029991
# 2019-03-04  0.531912
# 2019-03-05 -0.207109
# 2019-03-06  1.219661

# %% [markdown]
# #### 비교연산

# %%
df['A']>0
# Out:
# 2019-03-01     True
# 2019-03-02    False
# 2019-03-03     True
# 2019-03-04     True
# 2019-03-05    False
# 2019-03-06     True
# Freq: D, Name: A, dtype: bool

# %%
df[df['A']>0]
# Out:
#                    A         B         C         D
# 2019-03-01  1.104579 -0.400718 -0.578864 -0.212217
# 2019-03-03  0.029991 -0.836841  0.292812 -1.237906
# 2019-03-04  0.531912 -1.408266 -1.877995 -1.911272
# 2019-03-06  1.219661  0.830783  0.547277  0.087125

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2019-03-01  1.104579       NaN       NaN       NaN
# 2019-03-02       NaN  0.875059  1.503603       NaN
# 2019-03-03  0.029991       NaN  0.292812       NaN
# 2019-03-04  0.531912       NaN       NaN       NaN
# 2019-03-05       NaN       NaN       NaN       NaN
# 2019-03-06  1.219661  0.830783  0.547277  0.087125

# %% [markdown]
# #### 임의 적으로 순서변경 (재구성)

# %%
df2= pd.DataFrame(df, columns=['A','C','D','B'])
df2
# Out:
#                    A         C         D         B
# 2019-03-01  1.104579 -0.578864 -0.212217 -0.400718
# 2019-03-02 -0.230746  1.503603 -0.480797  0.875059
# 2019-03-03  0.029991  0.292812 -1.237906 -0.836841
# 2019-03-04  0.531912 -1.877995 -1.911272 -1.408266
# 2019-03-05 -0.207109 -0.411280 -0.390380 -0.913612
# 2019-03-06  1.219661  0.547277  0.087125  0.830783

# %% [markdown]
# #### 열 추가

# %%
df['E'] =np.nan  #numpy 의 nan으로
df
# Out:
#                    A         B         C         D   E
# 2019-03-01  1.104579 -0.400718 -0.578864 -0.212217 NaN
# 2019-03-02 -0.230746  0.875059  1.503603 -0.480797 NaN
# 2019-03-03  0.029991 -0.836841  0.292812 -1.237906 NaN
# 2019-03-04  0.531912 -1.408266 -1.877995 -1.911272 NaN
# 2019-03-05 -0.207109 -0.913612 -0.411280 -0.390380 NaN
# 2019-03-06  1.219661  0.830783  0.547277  0.087125 NaN

# %%
df['F']=df['A']+df['B']
df
# Out:
#                    A         B         C         D    E         F
# 2019-03-01  1.104579 -0.400718 -0.578864 -0.212217  NaN  0.703861
# 2019-03-02 -0.230746  0.875059  1.503603 -0.480797  2.0  0.644313
# 2019-03-03  0.029991 -0.836841  0.292812 -1.237906  NaN -0.806850
# 2019-03-04  0.531912 -1.408266 -1.877995 -1.911272  NaN -0.876354
# 2019-03-05 -0.207109 -0.913612 -0.411280 -0.390380  NaN -1.120721
# 2019-03-06  1.219661  0.830783  0.547277  0.087125  NaN  2.050443

# %% [markdown]
# ####  인덱스와  속성통해 값 대입

# %%
df.loc['2019-03-02',['E']]=2
df
# Out:
#                    A         B         C         D    E         F
# 2019-03-01  1.104579 -0.400718 -0.578864 -0.212217  NaN  0.703861
# 2019-03-02 -0.230746  0.875059  1.503603 -0.480797  2.0  0.644313
# 2019-03-03  0.029991 -0.836841  0.292812 -1.237906  NaN -0.806850
# 2019-03-04  0.531912 -1.408266 -1.877995 -1.911272  NaN -0.876354
# 2019-03-05 -0.207109 -0.913612 -0.411280 -0.390380  NaN -1.120721
# 2019-03-06  1.219661  0.830783  0.547277  0.087125  NaN  2.050443

# %% [markdown]
# ## 서울시 청소년 정신건강 분석

# %% [markdown]
# ### 데이터 정제

# %%
pd.read_excel('../data/teenage_mental.xls')  #커서 위치에 shift tab 누르면 가능한 것들이 나옴
# Out:
#      기간  구분  스트레스 인지율 스트레스 인지율.1 스트레스 인지율.2 우울감 경험률 우울감 경험률.1 우울감 경험률.2  \
# 0    기간  구분        전체        남학생        여학생      전체       남학생       여학생
# 1  2018   구분     42.7       34.5       51.5    29.6      24.2      35.4
#
#   자살 생각률 자살 생각률.1 자살 생각률.2
# 0     전체      남학생      여학생
# 1   15.4     11.8     19.2

# %%
pd.read_excel('../data/teenage_mental.xls',header=1)    #행 자르고 
pd.read_excel('../data/teenage_mental.xls',header=1,usecols="C:K")  #열 자르고
# Out:
#      전체   남학생   여학생  전체.1  남학생.1  여학생.1  전체.2  남학생.2  여학생.2
# 0  42.7  34.5  51.5  29.6   24.2   35.4  15.4   11.8   19.2

# %%
col_names=['스트레스','스트레스남학생','스트레스여학생','우울감경험률','우울남학생','우울여학생','자살생각율','자살남학생','자살여학생']
pd.read_excel('../data/teenage_mental.xls',header=1,usecols="C:K",names=col_names)  #column이름 재설정
# Out:
#    스트레스  스트레스남학생  스트레스여학생  우울감경험률  우울남학생  우울여학생  자살생각율  자살남학생  자살여학생
# 0  42.7     34.5     51.5    29.6   24.2   35.4   15.4   11.8   19.2

# %%
raw_data=pd.read_excel('../data/teenage_mental.xls',header=1,usecols="C:K",names=col_names)
# Out:
#    스트레스  스트레스남학생  스트레스여학생  우울감경험률  우울남학생  우울여학생  자살생각율  자살남학생  자살여학생
# 0  42.7     34.5     51.5    29.6   24.2   35.4   15.4   11.8   19.2

# %% [markdown]
# ####  행 하나 추가 _ 나머지 비율

# %%
raw_data.loc[1] =100  - raw_data.loc[0]
raw_data
# Out:
#    스트레스  스트레스남학생  스트레스여학생  우울감경험률  우울남학생  우울여학생  자살생각율  자살남학생  자살여학생
# 0  42.7     34.5     51.5    29.6   24.2   35.4   15.4   11.8   19.2
# 1  57.3     65.5     48.5    70.4   75.8   64.6   84.6   88.2   80.8

# %%
raw_data['응답']=['그렇다','아니다']
raw_data
# Out:
#      스트레스  스트레스남학생  스트레스여학생  우울감경험률  우울남학생  우울여학생  자살생각율  자살남학생  자살여학생   응답
# 응답
# 그렇다  42.7     34.5     51.5    29.6   24.2   35.4   15.4   11.8   19.2  그렇다
# 아니다  57.3     65.5     48.5    70.4   75.8   64.6   84.6   88.2   80.8  아니다

# %%
raw_data.set_index('응답',inplace=True)   #inplace True 는  r awdata 갱신  중요
raw_data
# Out:
#      스트레스  스트레스남학생  스트레스여학생  우울감경험률  우울남학생  우울여학생  자살생각율  자살남학생  자살여학생
# 응답
# 그렇다  42.7     34.5     51.5    29.6   24.2   35.4   15.4   11.8   19.2
# 아니다  57.3     65.5     48.5    70.4   75.8   64.6   84.6   88.2   80.8

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus']=False
f_patch = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname= f_patch).get_name()
rc('font', family = font_name)

# %%
raw_data
# Out:
#      스트레스  스트레스남학생  스트레스여학생  우울감경험률  우울남학생  우울여학생  자살생각율  자살남학생  자살여학생
# 응답
# 그렇다  42.7     34.5     51.5    29.6   24.2   35.4   15.4   11.8   19.2
# 아니다  57.3     65.5     48.5    70.4   75.8   64.6   84.6   88.2   80.8

# %%
raw_data['스트레스'].plot.pie()  #인덱스를 기준으로 나온다

# %%
raw_data['스트레스'].plot.pie(explode=[0,0.04]);

# %%
#figurea axes 으로 속성을 각각 지정 가능
f, ax =plt.subplots(1,3,figsize=(10,40))
raw_data['스트레스'].plot.pie(explode=[0,0.02],
                    ax=ax[0],autopct='%1.1f%%')
ax[0].set_title('스트레스를 받은적 있다')
ax[0].set_ylabel('')

raw_data['우울감경험률'].plot.pie(explode=[0,0.02],
                    ax=ax[1],autopct='%1.1f%%')
ax[1].set_title('우울중을 경험한적 있다')
ax[1].set_ylabel('')

raw_data['자살생각율'].plot.pie(explode=[0,0.02],
                    ax=ax[2],autopct='%1.1f%%')
ax[2].set_title('자살을 고민한적 있다')
ax[2].set_ylabel('')

plt.show()
